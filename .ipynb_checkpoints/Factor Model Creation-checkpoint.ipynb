# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import datetime
import matplotlib.pyplot as plt

# %%
# Pull the list of utility stock tickers from wikepedia
# store them in utlilities tickers
import requests
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
response = requests.get(url)
text = response.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(text)
tag_list = soup.find_all("tr")
utilities_tickers = list()
for tag in tag_list:
    try:
        if tag.find_all('td')[2].get_text() == 'Utilities':
            utilities_tickers.append(tag.find_all('td')[0].get_text().replace("\n", ""))        
    except IndexError:
        pass

# %%
import datetime as dt
from pandas_datareader import data as pdr
import yfinance as yfin

yfin.pdr_override()

start_date = dt.datetime(2010, 1, 1)
end_date = dt.datetime(2023, 1, 1)

utilities_stock_data = dict()

for ticker in utilities_tickers:
    df = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)
    df = df.reset_index()
    df['Date'] =  pd.to_datetime(df['Date'])
    utilities_stock_data[ticker] = df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#Add S&P500 and Nasdaq data
market_ticker = 'SPY'
spy_data = pdr.get_data_yahoo(market_ticker, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import requests
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
response = requests.get(url)
text = response.text
from bs4 import BeautifulSoup
soup = BeautifulSoup(text)
tag_list = soup.find_all("tr")
spy_tickers = list()
i=0
for tag in tag_list:
    i+=1
    if i > 503:
        break
    try:
        spy_tickers.append(tag.find_all('td')[0].get_text().replace("\n", ""))        
    except IndexError:
        pass

# %%
import datetime as dt
from pandas_datareader import data as pdr
import yfinance as yfin

yfin.pdr_override()

start_date = dt.datetime(2008, 1, 1)
end_date = dt.datetime(2023, 4, 1)

spy_stock_data = dict()

for ticker in spy_tickers:
    print(ticker)
    df = pdr.get_data_yahoo(ticker, start=start_date, end=end_date)
    df = df.reset_index()
    df['Date'] =  pd.to_datetime(df['Date'])

        
    spy_stock_data[ticker] = df
# Out:
# MMM
# [*********************100%***********************]  1 of 1 completed
# AOS
# [*********************100%***********************]  1 of 1 completed
# ABT
# [*********************100%***********************]  1 of 1 completed
# ABBV
# [*********************100%***********************]  1 of 1 completed
# ACN
# [*********************100%***********************]  1 of 1 completed
# ATVI
# [*********************100%***********************]  1 of 1 completed
# ADM
# [*********************100%***********************]  1 of 1 completed
# ADBE
# [*********************100%***********************]  1 of 1 completed
# ADP
# [*********************100%***********************]  1 of 1 completed
# AAP
# [*********************100%***********************]  1 of 1 completed
# AES
# [*********************100%***********************]  1 of 1 completed
# AFL
# [*********************100%***********************]  1 of 1 completed
# A
# [*********************100%***********************]  1 of 1 completed
# APD
# [*********************100%***********************]  1 of 1 completed
# AKAM
# [*********************100%***********************]  1 of 1 completed
# ALK
# [*********************100%***********************]  1 of 1 completed
# ALB
# [*********************100%***********************]  1 of 1 completed
# ARE
# [*********************100%***********************]  1 of 1 completed
# ALGN
# [*********************100%***********************]  1 of 1 completed
# ALLE
# [*********************100%***********************]  1 of 1 completed
# LNT
# [*********************100%***********************]  1 of 1 completed
# ALL
# [*********************100%***********************]  1 of 1 completed
# GOOGL
# [*********************100%***********************]  1 of 1 completed
# GOOG
# [*********************100%***********************]  1 of 1 completed
# MO
# [*********************100%***********************]  1 of 1 completed
# AMZN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ZION
# [*********************100%***********************]  1 of 1 completed
# ZTS
# [*********************100%***********************]  1 of 1 completed

# %%
#filter data into monthly data (1st of month) and add pct change in returns -s&p data
for ticker in spy_stock_data:
    spy_stock_data[ticker] = spy_stock_data[ticker].set_index('Date')  
    spy_stock_data[ticker] = spy_stock_data[ticker].resample('M').last()
    spy_stock_data[ticker]['pct change'] = spy_stock_data[ticker]['Adj Close'].pct_change()

# %%
#utilities data
for ticker in utilities_stock_data:
    utilities_stock_data[ticker]= utilities_stock_data[ticker].set_index('Date')
    utilities_stock_data[ticker] = utilities_stock_data[ticker].resample('M').last()
    utilities_stock_data[ticker]['pct change'] = utilities_stock_data[ticker]['Adj Close'].pct_change()
utilities_stock_data.pop('CEG')
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2022-01-31  46.000000  48.000000  46.000000  48.000000  47.397884    71300
# 2022-02-28  43.299999  46.619999  42.459999  45.980000  45.552280  5534900
# 2022-03-31  58.340000  59.080002  55.779999  56.250000  55.726753  3817600
# 2022-04-30  61.500000  61.860001  59.150002  59.209999  58.659218  2578400
# 2022-05-31  65.540001  66.389999  61.369999  62.080002  61.654049  7389300
# 2022-06-30  56.900002  58.834000  56.549999  57.259998  56.867115  2424400
# 2022-07-31  63.849998  66.599998  63.639999  66.099998  65.646461  3895200
# 2022-08-31  80.260002  82.389999  79.570000  81.589996  81.175377  3016500
# 2022-09-30  83.279999  84.449997  82.220001  83.190002  82.767250  3267800
# 2022-10-31  94.139999  95.419998  93.375000  94.540001  94.059570  2276600
# 2022-11-30  94.139999  96.940002  93.760002  96.120003  95.777847  3361800
# 2022-12-31  86.599998  86.599998  85.120003  86.209999  85.903114  1343300
#
#             pct change
# Date
# 2022-01-31         NaN
# 2022-02-28   -0.038939
# 2022-03-31    0.223358
# 2022-04-30    0.052622
# 2022-05-31    0.051055
# 2022-06-30   -0.077642
# 2022-07-31    0.154384
# 2022-08-31    0.236554
# 2022-09-30    0.019610
# 2022-10-31    0.136435
# 2022-11-30    0.018268
# 2022-12-31   -0.103100

# %%
# store data in dataframe
data = {}
for ticker in utilities_stock_data:
    data[ticker] = utilities_stock_data[ticker]['pct change']
utilities_returns = pd.DataFrame(data)
utilities_returns = utilities_returns.set_index(utilities_stock_data['AES'].index)
utilities_returns = utilities_returns.iloc[1: , :]
utilities_returns
# Out:
#                  AES       LNT       AEE       AEP       AWK       ATO  \
# Date
# 2010-02-28 -0.074426  0.013782 -0.032877 -0.017754  0.030870  0.006246
# 2010-03-31 -0.059025  0.051534  0.071344  0.016657 -0.022462  0.040422
# 2010-04-30  0.049091  0.040277 -0.004601  0.003511  0.000920  0.035351
# 2010-05-31 -0.110052 -0.060234 -0.050077 -0.056345 -0.057011 -0.071719
# 2010-06-30 -0.100292 -0.012446 -0.020436  0.010639  0.012783 -0.002950
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-31  0.145365  0.001805 -0.005369  0.024625 -0.040933 -0.060576
# 2022-09-30 -0.111984 -0.131881 -0.124761 -0.137226 -0.123206 -0.101693
# 2022-10-31  0.164475 -0.007126  0.012042  0.017004  0.116626  0.046146
# 2022-11-30  0.105505  0.079164  0.095682  0.111336  0.049115  0.135193
# 2022-12-31 -0.005533 -0.019361  0.002299 -0.019112  0.004349 -0.067637
#
#                  CNP       CMS        ED         D  ...        NI       NRG  \
# Date                                                ...
# 2010-02-28 -0.027143  0.016519 -0.008975  0.026256  ...  0.054035 -0.094153
# 2010-03-31  0.073244  0.012442  0.041871  0.082127  ...  0.051931 -0.043040
# 2010-04-30  0.000000  0.051747  0.014818  0.016784  ...  0.046439  0.156460
# 2010-05-31 -0.038307 -0.088686 -0.044927 -0.056932  ... -0.082208 -0.033926
# 2010-06-30 -0.033774 -0.002044  0.011975 -0.005647  ... -0.030749 -0.091649
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-08-31  0.000436 -0.010751 -0.007595 -0.002196  ... -0.029276  0.093510
# 2022-09-30 -0.106248 -0.137696 -0.122570 -0.148178  ... -0.146391 -0.072917
# 2022-10-31  0.015259 -0.020433  0.025653  0.012444  ...  0.029384  0.169340
# 2022-11-30  0.094143  0.079167  0.124543 -0.126626  ...  0.087583 -0.043919
# 2022-12-31 -0.036001  0.037007 -0.027846  0.014526  ... -0.018611 -0.250412
#
#                  PCG       PNW       PPL       PEG       SRE        SO  \
# Date
# 2010-02-28 -0.007576  0.016471 -0.034249 -0.028441 -0.031133 -0.007187
# 2010-03-31  0.022757  0.036254 -0.015142  0.004312  0.022785  0.043752
# 2010-04-30  0.032532  0.003610 -0.106459  0.088414 -0.014428  0.055845
# 2010-05-31 -0.052511 -0.059721  0.042407 -0.046685 -0.064661 -0.053820
# 2010-06-30  0.001205  0.035602 -0.019916  0.034422  0.025310  0.017737
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-31  0.135359  0.025589  0.000000 -0.019948 -0.005006  0.011168
# 2022-09-30  0.013788 -0.143862 -0.121587 -0.119246 -0.084805 -0.117685
# 2022-10-31  0.194400  0.055218  0.044970 -0.002845  0.006669 -0.037059
# 2022-11-30  0.051574  0.165303  0.114383  0.079900  0.101033  0.043922
# 2022-12-31  0.035669 -0.029111 -0.002417  0.021088 -0.063248  0.055736
#
#                  WEC       XEL
# Date
# 2010-02-28 -0.002122  0.001444
# 2010-03-31  0.020235  0.030484
# 2010-04-30  0.062741  0.025943
# 2010-05-31 -0.059635 -0.057931
# 2010-06-30  0.035510  0.017839
# ...              ...       ...
# 2022-08-31  0.000471  0.014621
# 2022-09-30 -0.132926 -0.132408
# 2022-10-31  0.021246  0.017344
# 2022-11-30  0.094332  0.078482
# 2022-12-31 -0.054267  0.005288
#
# [155 rows x 29 columns]

# %% [markdown]
# Original attempt was to create custom market factors for within the S&P universe. After extensive searching it was found impossible to collect the data required without paying for a service. Therefore an alternative method of evaluating the factor model was required.
#
# * Chose to implement Asness and Frazzini's HML calculation, and see how it performs not just in 5 factor (as in their literature) but also for 3 factor and 6 factor

# %% [markdown]
# Exploring the difference between Fama French factors vs Asness and Frazzini factors as explained in Asness, C.S, and Frazzini, A. (2013), The Devil in HML’s Details.
#
# Information on paper can be found: `https://www.aqr.com/Insights/Research/Journal-Article/The-Devil-in-HMLs-Details`
#
# Paper can be found: `https://www.iijournalseprint.com/JPM/AQR/Sum13DevilinHMLsDetails05t/index.html`
#
# Data can be found: `https://www.aqr.com/Insights/Datasets/The-Devil-in-HMLs-Details-Factors-Monthly`
#
# The Journal of Portfolio Management, Vol. 39, No. 4, pp. 49-68

# %% [markdown]
# # 3 Factor Model FF vs Asness and Frazzini

# %%
factorDF = pd.DataFrame()
for factor in ['MKT','HML Devil','HML FF','SMB', 'RF', 'UMD']:
    if factor != "RF":
        factorDF[factor] = pd.read_excel(
            "The Devil in HMLs Details Factors Monthly.xlsx", sheet_name=factor, index_col=0, header=18)['USA']
    else:
        factorDF[factor] = pd.read_excel(
            "The Devil in HMLs Details Factors Monthly.xlsx", sheet_name=factor, index_col=0, header=18)
factorDF = factorDF.loc['01/31/1927':] * 100
factorDF.index = pd.to_datetime(factorDF.index)
factorDF
# Out:
#                  MKT  HML Devil    HML FF       SMB        RF        UMD
# DATE
# 1927-01-31 -0.135455   4.040561  5.169132 -0.694753  0.250000   2.666435
# 1927-02-28  3.927366   2.439508  2.736957  0.352201  0.260000  -0.926118
# 1927-03-31 -0.031329  -0.030753 -0.703873 -1.044025  0.300000   5.165084
# 1927-04-30  0.525537  -0.530719  0.591798  0.911581  0.250000   3.060273
# 1927-05-31  5.510999  -0.188418  3.537726  1.504809  0.300000   5.326343
# ...              ...        ...       ...       ...       ...        ...
# 2022-09-30 -9.477230  -2.735168 -0.954866 -0.818938  0.239167   3.733427
# 2022-10-31  7.907763   5.021074  7.078106  0.040387  0.268333   5.794559
# 2022-11-30  4.712251   2.412721  0.787630 -3.686967  0.338333  -0.191695
# 2022-12-31 -6.215571  -0.438558  1.357774 -0.722112  0.355833   5.671376
# 2023-01-31  6.884736   4.757090 -3.718529  4.747774  0.358333 -15.371901
#
# [1153 rows x 6 columns]

# %%
factor_df = pd.read_csv('factor_FF_devil.csv', index_col=0)
factor_df.index = pd.to_datetime(factor_df.index, format='%Y%m') + datetime.timedelta(days=-1)
factor_df['HML devil'] = factor_df['HML devil'] * 100
factor_df
# Out:
#              MKT   SMB  HML FF  HML devil   RMW   CMA    RF    MOM   STR
# Date
# 1963-06-30 -0.39 -0.41   -0.97      -0.59  0.68 -1.18  0.27   0.90 -0.08
# 1963-07-31  5.07 -0.80    1.80       0.28  0.36 -0.35  0.25   1.01  1.30
# 1963-08-31 -1.57 -0.52    0.13       0.27 -0.71  0.29  0.27   0.19  1.19
# 1963-09-30  2.53 -1.39   -0.10      -2.11  2.80 -2.01  0.29   3.12 -0.66
# 1963-10-31 -0.85 -0.88    1.75       0.91 -0.51  2.24  0.27  -0.74  1.12
# ...          ...   ...     ...        ...   ...   ...   ...    ...   ...
# 2022-08-31 -9.35 -0.97    0.06      -2.74 -1.51 -0.84  0.19   3.47 -1.61
# 2022-09-30  7.83  1.86    8.05       5.02  3.07  6.52  0.23   3.87  0.33
# 2022-10-31  4.60 -2.67    1.38       2.41  6.01  3.11  0.29  -2.01  0.55
# 2022-11-30 -6.41 -0.16    1.32      -0.44  0.09  4.19  0.33   4.52 -3.42
# 2022-12-31  6.65  4.43   -4.05       4.76 -2.62 -4.53  0.35 -15.98  9.37
#
# [715 rows x 9 columns]

# %%
def sampleMeanVariant(sigmahat, muhat, rf, kappa):
    e = np.ones((sigmahat.shape[0], 1))
    H = (muhat - rf*e).T @ np.linalg.inv(sigmahat) @ (muhat - rf*e)
    aStar = (kappa-rf)/H * np.linalg.inv(sigmahat) @ (muhat - rf*e)
    return aStar

# %%
def factorModel(returns, factorDF, rf, kappa, numFactors):
    """ 
    returns - monthly returns dataframe of each equity (m,d)
    factorDF - df of excess market returns, SMB, HML
    rf - series of rf rate
    kappa - targeted expected return for portfolio
    numFactors - the number of factors in the model
    """

    d = returns.shape[1]
    # Compute the excess returns of each asset
    excess_returns = returns.sub(rf,axis=0).values

    # Define arrays to store the beta coefficients and residual variances
    betas = np.zeros((d, numFactors))
    residual_variances = np.zeros((d))

    # Perform the OLS regression for each asset
    for i in range(d):
        # Extract the excess returns of the i-th asset
        excess_asset_returns = excess_returns[:,i]

        # Define the OLS model with the R-rf ~ MF-rf + SMB + HML
        model = sm.OLS(excess_asset_returns,
                       sm.add_constant(factorDF))

        # Fit the model and extract the regression coefficients and residuals
        results = model.fit()
        beta = results.params[1:]
        residuals = results.resid

        # Store the beta coefficients and residual variance for the i-th asset
        betas[i] = beta
        residual_variances[i] = np.var(residuals, ddof=numFactors + 1)
        
    sigmaFactor = np.cov(factorDF.T)
    Dhat = np.diag(residual_variances)
    sigmahat = betas@sigmaFactor@betas.T + Dhat
    muhat = returns.mean(axis=0).values.reshape((-1, 1))
    
    # pass most recent rf 
    return sampleMeanVariant(sigmahat, muhat, rf[-1], kappa)

# %% [markdown]
# ### See how FF HML allocation compares to Asness and Frazzini HML allocation in 3 Factor

# %%
AF_factorDF = factor_df[['MKT', 'SMB', 'HML devil']].loc['02/28/2010':'12/31/2022']
rf_DF = factorDF['RF'].loc['02/28/2010':'12/31/2022']
AF_a = factorModel(utilities_returns, HML_factorDF, rf_DF, kappa=.12,numFactors=3)
print(sum(AF_a))
AF_a
# Out:
# [0.68396358]
# array([[-0.02162627],
#        [ 0.02013557],
#        [ 0.03441779],
#        [ 0.03153972],
#        [ 0.03614935],
#        [ 0.01927468],
#        [-0.00033887],
#        [ 0.03971461],
#        [ 0.04086803],
#        [ 0.03322995],
#        [ 0.02459544],
#        [ 0.04019181],
#        [ 0.01319525],
#        [ 0.01574888],
#        [ 0.02777047],
#        [ 0.02806554],
#        [ 0.0212636 ],
#        [ 0.0335473 ],
#        [ 0.0368062 ],
#        [ 0.02085818],
#        [-0.00528412],
#        [ 0.0002608 ],
#        [ 0.02812724],
#        [ 0.01295789],
#        [ 0.02677579],
#        [ 0.01111099],
#        [ 0.03687066],
#        [ 0.03931272],
#        [ 0.03842439]])

# %%
FF_factorDF = factor_df[['MKT', 'SMB', 'HML FF']].loc['02/28/2010':'12/31/2022']
FF_a = factorModel(utilities_returns, FF_factorDF, rf_DF, kappa=.12, numFactors=3)
print(sum(FF_a))
FF_a
# Out:
# [0.68344214]
# array([[0.01821496],
#        [0.02510451],
#        [0.02867691],
#        [0.02449045],
#        [0.02901824],
#        [0.02459663],
#        [0.0214433 ],
#        [0.02668114],
#        [0.0251379 ],
#        [0.02427085],
#        [0.02396723],
#        [0.02787731],
#        [0.02041764],
#        [0.02285238],
#        [0.02070477],
#        [0.02717838],
#        [0.02348088],
#        [0.01549048],
#        [0.03039925],
#        [0.02555258],
#        [0.01054444],
#        [0.01175933],
#        [0.02668637],
#        [0.02251448],
#        [0.02320619],
#        [0.0221451 ],
#        [0.02420534],
#        [0.0267319 ],
#        [0.03009321]])

# %% [markdown]
# ### Rolling Window

# %%
def roll_factor(d, M, T, returns, factors):
    '''
    d: number of assets
    M: size of window in terms of months
    T: total number of periods
    returns: T x d dataframe of returns for d assets for T total periods
    factors: factors to be used in factor model
    '''
       
    X = np.zeros(T-M)
    dates = pd.to_datetime(returns.index)
    
    for t in range(M,T):
        # get training and testing set
        start = dates[t-M]
        end = dates[t]
        R_train = returns.loc[start:end]
        R_test = returns.loc[end]
        
        # apply factor model
        rf = factorDF['RF'].loc[start:end]
        
        # get allocation weights
        a = factorModel(R_train, factor_df[factors].loc[start:end], rf, kappa=0.12, numFactors=len(factors))
    
        # get return of next period
        X[t-M] = a.T @ R_test + (1 - np.sum(a)) * rf[-1]
    
    return X

# %%
d = len(utilities_returns.columns)
M = [1*12, 2*12, 4*12]
T = len(utilities_returns)

# %%
def compare_FF_devil(factors):
    FF_factors = factors.copy()
    FF_factors.append('HML FF')
    AF_factors = factors.copy()
    AF_factors.append('HML devil')
    
    for m in M:
        FF = roll_factor(d, m, T, utilities_returns, FF_factors)
        AF = roll_factor(d, m, T, utilities_returns, AF_factors)
        
        plt.axhline(y = np.mean(FF), color = 'blue', linestyle = '-')
        plt.axhline(y = np.mean(AF), color = 'orange', linestyle = '-')
        
        df = pd.DataFrame({'FF':FF, 'AF':AF})
        df = df.rolling(48).mean() # rolling of rolling
        
        plt.plot(df['FF'], label='FF m=%d' % m)
        plt.plot(df['AF'], label='AF m=%d' % m)
        plt.xlim([0, T])
        plt.legend()
        plt.show()

# %%
compare_FF_devil(['MKT','SMB'])

# %%
compare_FF_devil(['MKT','SMB','RMW', 'CMA'])

# %%
compare_FF_devil(['MKT','SMB','MOM', 'STR'])

# %%
compare_FF_devil(['MKT','SMB','RMW', 'CMA', 'MOM'])

# %% [markdown]
# ### 5 or 6 factor implementation should be identical and should be able to actually use the same function

# %% [markdown]
# # Things to Look into:
#
# 1. Devil vs FF performance in 3 factor
# 2. Devil vs FF performance in 5 factor (use FF data for all 4 factors and just swap in devil vs not devil)
# 3. Devil vs FF performance in 6 factor (5 factor with momentum factor)
# 4. What is a good rolling window to use for calculation? 5 years back? 2 years? 1 year? how does our window choice effect returns? What is the optimal Window?
#     * What does this say on how long the market stays constant for?

# %% [markdown]
# # Needed from code perspective:
# * Overall loop to set lookback and run rolling window
# * Data for 5 and 6 factor models
# * Returns calculation given allocation provided by `factorModel`
# * Performance Metrics
